# %% [markdown]
# # Day 1 - Intro to Python

# %%
# BLOCK 1  - run this block to see an example of a print statement

print("Hello Quantum World")

# %%
# BLOCK 2 - Print your own statement

# %%
# BLOCK 3 - Create a print statement and leave a comment

# %%
# BLOCK 4 - Print the answer to the question: What grade are you in?

# %%
# BLOCK 5 - Print the answer to the question: How many pets do you have?

# %%
# BLOCK 6 - run this block to see how a variable works

cats = 3

# %%
# BLOCK 7 - Create a variable and store a number

# %%
# BLOCK 8 - run this block to see how to print the value of a variable

cats= 3
print(cats)
# Out:
# cats

# %%
# BLOCK 9 - Create a variable called pets and store the number of pets you have. 
#Then print the value of the variable.

# %%
# BLOCK 10 - Create a variable called siblings and store the number of siblings you have. 
#Then print the value of the variable.

# %%
# BLOCK 11 - run this block to see how to store a word in a variable

name = "Sarah"
print(name)

# %%
# BLOCK 12 - Create a variable called name to store your name. Then print it out.

# %%
# BLOCK 13 - Create a variable called school to store the name of your school. 
#Then print it out.

# %%
# BLOCK 14  - Run this block to see how to combine words and variables

name = "Sarah"
print("My name is " + name)

# %%
# BLOCK 15 - Create a variable called name to store your name, and then print the sentence:

# My name is _______

# %%
# BLOCK 16 - Using your name and school variables, print the following sentence:

# My name is ____ and I go to _______

# %%
# BLOCK 17 - Define two variables containing numbers and add them together

# %%
# BLOCK 18 - Define two variables containing numbers and multiply them together
